# %%
model = 'aae'
d_model = 128
d_feedforward = 128
d_latent = 128
data_source = 'peptide'
epochs = 1
hardware = 'gpu'
property_predictor = 'ON'
type_property_predictor = 'deep_net'
train_props_path = 'data\\function_train.txt'
test_props_path = 'data\\function_test.txt'
#DDP
init_method = 'file:///D:/libtmp/file'
dist_backend = 'gloo' #on windows NCCL not supported
DDP = 'OFF' #ON or OFF
# %run scripts/train.py --model $model --d_model $d_model --d_feedforward $d_feedforward --d_latent $d_latent --data_source $data_source --epochs $epochs --hardware $hardware --init_method $init_method --dist_backend $dist_backend --DDP $DDP --property_predictor $property_predictor --type_property_predictor $type_property_predictor --train_props_path $train_props_path --test_props_path $test_props_path
# Out:
# main function called /n
# train_parser function called /n
# train function called /n
# parser model_init called /n
# {'ADAM_LR': 0.0003, 'ANNEAL_START': 0, 'BATCH_CHUNKS': 1, 'BATCH_SIZE': 50, 'BETA': 0.05, 'BETA_INIT': 1e-08, 'EPS_SCALE': 1, 'HARDWARE': 'gpu', 'LR_SCALE': 1, 'WARMUP_STEPS': 10000, 'INIT_METHOD': 'file:///D:/libtmp/file', 'DIST_BACKEND': 'gloo', 'WORLD_SIZE': 1, 'DISTRIBUTED': False, 'NUM_WORKERS': 0, 'DDP': True, 'DISCRIMINATOR_LAYERS': [640, 256], 'CHAR_WEIGHTS': tensor([0.8297, 0.7935, 0.8469, 0.8466, 0.9337, 0.8347, 0.8172, 0.8825, 0.8868,
#         0.8697, 0.7926, 0.8549, 0.9855, 0.9683, 0.9080, 0.8134, 1.0000, 0.8835,
#         0.9525, 0.8972, 0.1000, 0.9059]), 'CHAR_DICT': {'<start>': 0, 'A': 1, 'L': 2, 'V': 3, 'S': 4, 'Q': 5, 'C': 6, 'R': 7, 'P': 8, 'T': 9, 'E': 10, 'K': 11, 'I': 12, 'H': 13, 'W': 14, 'D': 15, 'G': 16, 'M': 17, 'F': 18, 'Y': 19, 'N': 20, '_': 21, '<end>': 22}, 'ORG_DICT': {0: 'A', 1: 'L', 2: 'V', 3: 'S', 4: 'Q', 5: 'C', 6: 'R', 7: 'P', 8: 'T', 9: 'E', 10: 'K', 11: 'I', 12: 'H', 13: 'W', 14: 'D', 15: 'G', 16: 'M', 17: 'F', 18: 'Y', 19: 'N', 20: '_', 21: '<end>'}}
# echo GPUs per node: 1
# local:  None  node:  None
# cuda visible:  None
# echo From Rank: 0, ==> Initializing Process Group...
# process group ready!
# From Rank: 0, ==> Making model..
# echo final check; ngpus_per_node=1,local_rank=0,rank=0,available_gpus=1,current_device=cuda:0
# passed distributed data parallel call
# aae-128_peptide
# aae-128_peptide
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\Documents\GitHub\MSCSAM_TBD\main_model\scripts\train.py in <module>
#     107     parser = train_parser()
#     108     args = parser.parse_args()
# --> 109     train(args)
#
# ~\Documents\GitHub\MSCSAM_TBD\main_model\scripts\train.py in train(args)
#      99     if args.checkpoint is not None:
#     100         vae.load(args.checkpoint)
# --> 101     vae.train(train_mols, test_mols, train_props, test_props,
#     102               epochs=args.epochs, save_freq=args.save_freq)
#     103
#
# ~\Documents\GitHub\MSCSAM_TBD\main_model\transvae\trans_models.py in train(self, train_mols, val_mols, train_props, val_props, epochs, save, save_freq, log, log_dir)
#     297
#     298                     if self.model_type == 'aae': #the aae loss takes the discriminator output, latent space and optimizer as input
# --> 299                         loss, bce, kld, prop_bce, disc_loss = self.model(src, tgt, true_prop,self.params['CHAR_WEIGHTS'], beta,
#     300                                                                               self.optimizer, 'train', src_mask, tgt_mask)
#     301 #                         loss, bce, kld, prop_bce, disc_loss = aae_loss(src, x_out, mu, logvar,
#
# ~\Anaconda3\envs\amp21\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Anaconda3\envs\amp21\lib\site-packages\torch\nn\parallel\distributed.py in forward(self, *inputs, **kwargs)
#     617             inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#     618             if len(self.device_ids) == 1:
# --> 619                 output = self.module(*inputs[0], **kwargs[0])
#     620             else:
#     621                 outputs = self.parallel_apply(self._module_copies[:len(inputs)], inputs, kwargs)
#
# ~\Anaconda3\envs\amp21\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Documents\GitHub\MSCSAM_TBD\main_model\transvae\aae_models.py in forward(self, src, tgt, true_prop, weights, beta, optimizer, train_test, src_mask, tgt_mask)
#     130         else:
#     131             prop = None
# --> 132         tot_loss, bce, kld, prop_bce, disc_loss = loss.aae_loss(src, x, mu, logvar,
#     133                                                                   true_prop, prop,
#     134                                                                   weights,
#
# ~\Documents\GitHub\MSCSAM_TBD\main_model\transvae\loss.py in aae_loss(x, x_out, mu, logvar, true_prop, pred_prop, weights, self, latent_codes, opt, train_test, beta)
#      96
#      97     if 'train' in train_test:
# ---> 98         total_loss.backward() #backpropagating
#      99         opt.d_opt.step()
#     100
#
# ~\Anaconda3\envs\amp21\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\Anaconda3\envs\amp21\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# RuntimeError: Trying to backward through the graph a second time, but the saved intermediate results have already been freed. Specify retain_graph=True when calling backward the first time.

# %%
from transvae import analysis
#loss ploting
src = 'trials//log_rnn-128_peptide.txt'
analysis.plot_loss_by_type(src)#, loss_type = 'kld_loss', data_type='test')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\s_renaud\\Anaconda3\\envs\\amp21\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#extracting attention weights
# %run scripts/attention.py --model transvae --model_ckpt checkpointz\\trans_amp\\2000_trans1x-128_peptide.ckpt --mols notebooks\\example_data\\peptides.txt --save_path "attn_weights"
# Out:
# attn parser function called /n
# None
# G:\GitHub\MSCSAM_TBD\main_model\transvae\trans_models.py:51: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.params['CHAR_WEIGHTS'] = torch.tensor(self.params['CHAR_WEIGHTS'], dtype=torch.float)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# G:\GitHub\MSCSAM_TBD\main_model\scripts\attention.py in <module>
#     107     parser = attn_parser()
#     108     args = parser.parse_args()
# --> 109     calc_attention(args)
#
# G:\GitHub\MSCSAM_TBD\main_model\scripts\attention.py in calc_attention(args)
#      32
#      33     ### Load data and prepare for iteration
# ---> 34     data = vae_data_gen(data, props=None, char_dict=vae.params['CHAR_DICT'])
#      35     data_iter = torch.utils.data.DataLoader(data,
#      36                                             batch_size=args.batch_size,
#
# G:\GitHub\MSCSAM_TBD\main_model\transvae\data.py in vae_data_gen(***failed resolving arguments***)
#      29     if not name == None and name.split('_')[1]=='peptide':  #separate sequence into list of chars e.g. 'CC1c2'-->['C''C''1''c''2']
#      30         seq_list = [peptide_tokenizer(x) for x in seq_list]     #use peptide_tokenizer
# ---> 31     else:
#      32         seq_list = [tokenizer(x) for x in seq_list]
#      33     encoded_data = torch.empty((len(seq_list), max_len+2)) #empty tensor: (length of entire input data, max_seq_len + 2->{start & end})
#
# G:\GitHub\MSCSAM_TBD\main_model\transvae\data.py in <listcomp>(.0)
#      29     if not name == None and name.split('_')[1]=='peptide':  #separate sequence into list of chars e.g. 'CC1c2'-->['C''C''1''c''2']
#      30         seq_list = [peptide_tokenizer(x) for x in seq_list]     #use peptide_tokenizer
# ---> 31     else:
#      32         seq_list = [tokenizer(x) for x in seq_list]
#      33     encoded_data = torch.empty((len(seq_list), max_len+2)) #empty tensor: (length of entire input data, max_seq_len + 2->{start & end})
#
# G:\GitHub\MSCSAM_TBD\main_model\transvae\tvae_util.py in tokenizer(smile)
#     103     regezz = re.compile(pattern)
#     104     tokens = [token for token in regezz.findall(smile)]
# --> 105     assert smile == ''.join(tokens), ("{} could not be joined".format(smile))
#     106     return tokens
#     107
#
# AssertionError: EGFQLMDRGTFDEIGR could not be joined
